# %%
from locfdr import locfdr

f = open('samplez.tsv')
zz = []

for line in f:
    zz.append(float(line.strip()))

results = locfdr(zz)
print('Executed simulation described in Section 4 of the locfdr() R vignette at http://cran.r-project.org/web/packages/locfdr/vignettes/locfdr-example.pdf . See results in variable \'results\'.')
# Out:
# /u/scratch/k/kangchen/locfdr/locfdr-python/locfdr.py:164: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   imax = l.argmax()
# Executed simulation described in Section 4 of the locfdr() R vignette at http://cran.r-project.org/web/packages/locfdr/vignettes/locfdr-example.pdf . See results in variable 'results'.

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
from locfdr import locfdr

# %%
try:
    xrange
except NameError:
    xrange = range

# %%
results = locfdr(zz)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-72c2d2b006c5> in <module>
# ----> 1 results = locfdr(zz)
#
# /u/scratch/k/kangchen/locfdr/locfdr-python/locfdr.py in locfdr(zz, bre, df, pct, pct0, nulltype, type, plot, mult, mlests, main, sw, verbose, showplot, saveplot, saveroot, saveext, savestamp)
#     221         p0 = sum(f0) / float(sum(f))
#     222         f0 = f0 / p0
# --> 223         fp0.loc['cmest'][2] = p0
#     224     b = 4.3 * np.exp(-0.26 * np.log10(N))
#     225     if mlests == None:
#
# /u/scratch/k/kangchen/locfdr/locfdr-python/locfns.py in locmle(z, xlim, Jmle, d, s, ep, sw, Cov_in)
#      47     borig = xlim[0] + xlim[1]
#      48     z0 = np.array([el for el in z if el >= aorig and el <= borig])
# ---> 49     N0 = len(z0)
#      50     Y = np.array([np.mean(z0), np.mean(np.power(z0, 2))])
#      51     that = float(N0) / N
#
# NameError: name 'xrange' is not defined
